# %%
import torch
print(torch.cuda.is_available())  # should print True
print(torch.cuda.get_device_name(0))  # should print your GPU name
# Out:
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import torch
#       2 print(torch.cuda.is_available())  # should print True
# ----> 3 print(torch.cuda.get_device_name(0))  # should print your GPU name
#
# File ~\PycharmProjects\Political_Bias\.venv\Lib\site-packages\torch\cuda\__init__.py:766, in get_device_name(device)
#     754 def get_device_name(device: Device = None) -> str:
#     755     r"""Get the name of a device.
#     756
#     757     Args:
#    (...)    764         str: the name of the device
#     765     """
# --> 766     return get_device_properties(device).name
#
# File ~\PycharmProjects\Political_Bias\.venv\Lib\site-packages\torch\cuda\__init__.py:799, in get_device_properties(device)
#     787 def get_device_properties(device: Device = None) -> _CudaDeviceProperties:
#     788     r"""Get the properties of a device.
#     789
#     790     Args:
#    (...)    797         _CudaDeviceProperties: the properties of the device
#     798     """
# --> 799     _lazy_init()  # will define _get_device_properties
#     800     device = _get_device_index(device, optional=True)
#     801     if device < 0 or device >= device_count():
#
# File ~\PycharmProjects\Political_Bias\.venv\Lib\site-packages\torch\cuda\__init__.py:584, in _lazy_init()
#     579     raise RuntimeError(
#     580         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     581         "multiprocessing, you must use the 'spawn' start method"
#     582     )
#     583 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 584     raise AssertionError("Torch not compiled with CUDA enabled")
#     585 if _cudart is None:
#     586     raise AssertionError(
#     587         "libcudart functions unavailable. It looks like you have a broken build?"
#     588     )
#
# AssertionError: Torch not compiled with CUDA enabled
